# %% [markdown]
# # Predicting Bitcoin Prices via Mathematical and Financial Models: A Study of Fundamental and Speculative Components
#
# ## Author: Amin Boulouma

# %% [markdown]
# ### Problem
#
# The problem is to develop a predictive model for the bitcoin market prices that can accurately forecast the price at time $t+1$ based on the price at time $t$.
#
# ### Research Question
#
# What is the best predictive model to use for forecasting bitcoin market prices, and what is the predictive power of each model?

# %% [markdown]
# # Model 1 - Heterogeneous agent model developed by Brock and Hommes (1998)

# %% [markdown]
# The first model we use is based on the standard framework for estimating the speculative bubble component in asset prices. This model assumes that asset prices can be decomposed into two components: a fundamental component and a speculative component. The fundamental component is driven by the intrinsic value of the asset, while the speculative component is driven by market sentiment and investors' expectations.
#
# To estimate the fundamental component of Bitcoin prices, we use a range of economic indicators, including the hash rate, transaction volume, and mining difficulty. We also consider the macroeconomic environment, such as inflation rates and interest rates, to account for the broader economic context in which Bitcoin operates.
#
# To estimate the speculative component of Bitcoin prices, we use a variety of technical indicators, including moving averages, relative strength index (RSI), and the stochastic oscillator. We also use sentiment analysis of social media and news articles to gauge market sentiment and investor expectations.
#
# ## The Model
#
# The Heterogeneous agent model developed by Brock and Hommes (1998) assumes that the asset price $P_t$ can be decomposed into a fundamental component $F_t$ and a speculative component $S_t$ as follows:
#
# $$P_t = F_t + S_t$$
#
# We can apply this formula for the Bitcoin price.
#
# The fundamental component of Bitcoin prices can be estimated using the following equation:
#
# $$F_t = \omega_0 + \sum_{j=1}^{N} \omega_j X_{j,t}$$
#
# where $F_t$ is the fundamental component of Bitcoin prices at time $t$, $X_{j,t}$ are the **economic indicators** and **macroeconomic factors** at time $t$, $N$ is the total number of indicators and factors, and $\omega_j$ are the corresponding weights.
#
# We can see those **economic indicators** and **macroeconomic factors** as the following:
#
# $$ F_t = \omega_0 + w_1 \cdot H_t + w_2 \cdot TV_t + w_3 \cdot MD_t + w_4 \cdot IR_t $$
#
# Where:
#
# - $F_t$ is the fundamental component of Bitcoin prices at time $t$
# - $H_t$ is the hash rate of the Bitcoin network at time $t$
# - $TV_t$ is the transaction volume on the Bitcoin network at time $t$
# - $MD_t$ is the mining difficulty of the Bitcoin network at time $t$
# - $IR_t$ is the inflation rate at time $t$
# - $w_1, w_2, w_3 and $w_4$ are weights assigned to each of the economic indicators and macroeconomic factors, respectively.
#
# The speculative component of Bitcoin prices can be estimated using the following equation:
#
# $$S_t = \sum_{j=1}^{M} \alpha_j Y_{j,t} + \beta S_{t-1}$$
#
# where $S_t$ is the speculative component of Bitcoin prices at time $t$, $Y_{j,t}$ are the **technical indicators** and **sentiment analysis** at time $t$, $M$ is the total number of technical indicators and sentiment analysis, $\alpha_j$ are the corresponding weights, and $\beta$ is the persistence parameter.
#
# $Y_{j,t}$, which represents the $j$th technical indicator or sentiment analysis at time $t$, can be written as:
#
# $$Y_{j,t} = f_j (P_t, V_t, M_t, N_t, S_t, A_t, E_t)$$
#
# where $P_t$ is the price of Bitcoin at time $t$, $V_t$ is the trading volume of Bitcoin at time $t$, $M_t$ is the mining difficulty of Bitcoin at time $t$, $N_t$ is the number of active Bitcoin nodes at time $t$, $S_t$ is the market sentiment of Bitcoin at time $t$, $A_t$ is the adoption rate of Bitcoin at time $t$, and $E_t$ is the external news and events related to Bitcoin at time $t$. The function $f_j$ represents the specific technical indicator or sentiment analysis being used, and may have different inputs and parameters depending on the indicator.
#
# For example, the formula for the moving average indicator ($MA$) with a window size of $k$ can be written as:
#
# $$Y_{MA,t} = \frac{1}{k} \sum_{i=t-k+1}^{t} P_i$$
#
# where $P_i$ is the price of Bitcoin at time $i$.
#
# Similarly, the formula for the relative strength index ($RSI$) with a window size of $k$ can be written as:
#
# $$Y_{RSI,t} = 100 - \frac{100}{1 + RS}$$
#
# where $RS$ is the relative strength at time $t$, which is calculated as:
#
# $$RS = \frac{\sum_{i=t-k+1}^{t} Max(P_i - P_{i-1}, 0)}{\sum_{i=t-k+1}^{t} |P_i - P_{i-1}|}$$
#
# The formula for the stochastic oscillator ($SO$) with a window size of $k$ can be written as:
#
# $$Y_{SO,t} = \frac{P_t - Min_{k}(P)}{Max_{k}(P) - Min_{k}(P)} \times 100$$
#
# where $Min_{k}(P)$ and $Max_{k}(P)$ are the minimum and maximum prices of Bitcoin over the past $k$ periods, respectively.
#
# Another $f_j$ can be the Google Trend indicator $f_{GT}(Q_t)$
#
# $$Y_{GT,t} = f_{GT}(Q_t)$$
#
# where $Q_t$ represents the search query related to Bitcoin at time $t$, and $f_{GT}$ is a function that processes the search data to generate a Google Trends score.
#
# The Google Trends score is a relative measure of the search interest for a particular query over time. It is calculated by normalizing the search volume for a given query over a specific time period and location to the total search volume for all queries in that time period and location. The resulting score ranges from 0 to 100, with 100 indicating the highest relative search interest.
#
# ## The Calibration of the Model
#
# The calibration of the model involves determining the values of the parameters that produce the best fit between the model predictions and the actual data. In our case, we will use historical Bitcoin price data and corresponding economic, technical, and sentiment indicators to calibrate the model.
#
# Sure, here's the previous message I posted about the calibration of the model:
#
# To calibrate the model, we use historical data to estimate the weights $\omega_j$, $\alpha_j$, and $\beta$, as well as the initial values of $S_0$ and $F_0$. We can use a standard least-squares regression to estimate the weights and initial values. Specifically, we can use the following steps:
#
# 1. We gather historical data on the economic and technical indicators, as well as the Bitcoin price, trading volume, mining difficulty, number of active nodes, market sentiment, adoption rate, and external news and events.
#
# 2. We calculate the values of the economic indicators and technical indicators for each time period in the historical data.
#
# 3. We calculate the values of the fundamental and speculative components of the Bitcoin price using the equations for $F_t$ and $S_t$.
#
# 4. We estimate the weights $\omega_j$, $\alpha_j$, and $\beta$, as well as the initial values of $S_0$ and $F_0$, by running a least-squares regression on the historical data. Specifically, we can use the following regression equation:
#
# $$ P_t = F_t + S_t + \epsilon_t $$
#
# where $\epsilon_t$ is the error term at time $t$. We can estimate the coefficients $\omega_j$, $\alpha_j$, and $\beta$, as well as the intercept term and the initial values of $S_0$ and $F_0$, by minimizing the sum of squared errors:
#
# ### Sum of Squared Errors
#
# $$ SSE = \sum_{t=1}^{T} \epsilon_t^2 $$
#
# where $T$ is the total number of time periods in the historical data.
#
# We validate the calibrated model by comparing the predicted Bitcoin prices to the actual Bitcoin prices in a holdout sample of the historical data. We can use metrics such as the mean squared error (MSE), the mean absolute error (MAE) and the root mean squared error (RMSE) to evaluate the accuracy of the predictions.
# Let me know if you need any further clarification or elaboration on this.
#
# ### Root Mean Squared Error (RMSE)
#
# The RMSE is the square root of the average of squared differences between predicted and actual values. It is a commonly used metric to measure the accuracy of regression models. The formula for RMSE is:
#
# \begin{equation}
# RMSE = \sqrt{\frac{1}{n}\sum_{i=1}^{n} (y_i - \hat{y}_i)^2}
# \end{equation}
#
# where $y_i$ is the actual value of the dependent variable, $\hat{y}_i$ is the predicted value of the dependent variable, and $n$ is the number of observations.
#
# ### Mean Squared Error (MSE)
#
# The MSE is the average of squared differences between predicted and actual values. It is another commonly used metric to measure the accuracy of regression models. The formula for MSE is:
#
# \begin{equation}
# MSE = \frac{1}{n}\sum_{i=1}^{n} (y_i - \hat{y}_i)^2
# \end{equation}
#
# where $y_i$ is the actual value of the dependent variable, $\hat{y}_i$ is the predicted value of the dependent variable, and $n$ is the number of observations.
#
# ### Mean Absolute Error (MAE)
#
# The MAE is the average of absolute differences between predicted and actual values. It is another commonly used metric to measure the accuracy of regression models. The formula for MAE is:
#
# \begin{equation}
# MAE = \frac{1}{n}\sum_{i=1}^{n} |y_i - \hat{y}_i|
# \end{equation}
#
# where $y_i$ is the actual value of the dependent variable, $\hat{y}_i$ is the predicted value of the dependent variable, and $n$ is the number of observations.
#
# We use these metrics to evaluate the performance of our regression model. A lower value for these metrics indicates better performance.

# %% [markdown]
# ## The implementation

# %% [markdown]
# 1. Import necessary libraries:

# %%
from btc_analysis import (
    plot_price_over_time,
    plot_hash_rate_vs_mining_difficulty,
    plot_transaction_volume_per_year,
    plot_inflation_rate_over_time,
    plot_price_vs_hash_rate_over_time,
    plot_mining_difficulty_by_year,
    plot_correlation_heatmap,
    plot_fundamental_component,
    plot_technical_sentiment_indicators,
    calculate_fundamental_component,
    calculate_speculative_component,
    calculated_predicted_price,
    plot_heterogeneous_agent_model
)

from btc_data import read_data, clean_and_transform_data, clean_data

# %% [markdown]
# 2. Collect historical data of Bitcoin:

# %%
btc_full_df = read_data("datasets/btc.csv")
btc_google_trend_df = read_data("datasets/btc_google_trend.csv")
# Out:
# /var/folders/gc/m0hv5jzd1kn2nrn5y5w241g00000gn/T/ipykernel_5944/4227500506.py:1: DtypeWarning: Columns (146) have mixed types.Specify dtype option on import or set low_memory=False.
#   btc_full_df = read_data("datasets/btc.csv")

# %% [markdown]
# 6. Collect necessary data for estimating the fundamental component of Bitcoin prices:
#
# The inflation rate and interest rate of Bitcoin can be calculated using the following data:
#
# - `IssTotNtv`: The total number of Bitcoins that have been mined since the creation of the Bitcoin network.
# - `SplyCur`: The current circulating supply of Bitcoin.
#
# To calculate the inflation rate, we can use the following formula:
#
# ```inflation_rate = IssTotNtv / SplyCur)```
#
# This formula calculates the percentage increase in the total supply of Bitcoin since its creation, and subtracts 1 to convert it to a percentage increase per year. As of February 23, 2023, the inflation rate of Bitcoin is approximately 1.58%.

# %%
btc_df = clean_and_transform_data(btc_full_df, btc_google_trend_df)

# %% [markdown]
# 7. Visualize the data

# %% [markdown]
# ### 1. Line plot of Bitcoin Price over Time:

# %%
plot_price_over_time(btc_df)

# %% [markdown]
# A line plot is a basic visualization that shows the trend of a variable over time. In this case, the line plot of Bitcoin price over time shows the change in price of Bitcoin over a certain period. This plot helps to easily observe the upward or downward trends of Bitcoin price and also helps to identify patterns such as seasonality, trends, and cycles.

# %% [markdown]
# ### 2. Scatter plot of Hash Rate vs. Mining Difficulty:

# %% [markdown]
# A scatter plot is a graphical representation of the relationship between two variables. In this plot, hash rate and mining difficulty are represented on the X-axis and Y-axis, respectively. Scatter plot of hash rate vs. mining difficulty helps to identify the correlation between the two variables. If the points in the plot are closer together, there is a strong correlation between the two variables.

# %%
plot_hash_rate_vs_mining_difficulty(btc_df)

# %% [markdown]
# Bar plot of Transaction Volume per Year:

# %% [markdown]
# A bar plot is a graphical representation of the distribution of a categorical variable. In this plot, the transaction volume is grouped by year and represented by vertical bars. The height of each bar indicates the transaction volume for each year. This plot helps to compare the transaction volume for different years and also shows the trend in transaction volume over time.

# %%
plot_transaction_volume_per_year(btc_df)

# %% [markdown]
# Area plot of Inflation Rate over Time:

# %% [markdown]
# An area plot is a plot that represents the magnitude of a variable over time. In this plot, inflation rate and interest rate are represented by the area under their respective curves. The plot helps to show the change in inflation rate and interest rate over time and also the magnitude of the difference between the two variables. It helps to observe the trend of the variables and the seasonality, trends, and cycles that they exhibit.

# %%
plot_inflation_rate_over_time(btc_df)

# %% [markdown]
# Scatter plot of Price vs. Hash Rate over time:

# %%
plot_price_vs_hash_rate_over_time(btc_df)

# %% [markdown]
# This scatter plot shows the relationship between the price of Bitcoin and the hash rate (computational power used for mining) over time. The color of each data point represents the hash rate. We can see that as the hash rate increases, the price tends to increase as well.

# %% [markdown]
# Stacked bar chart of Mining Difficulty by year:

# %%
plot_mining_difficulty_by_year(btc_df)

# %% [markdown]
# This stacked bar chart shows the total mining difficulty of Bitcoin for each year. We can see that the mining difficulty has increased dramatically over time, which reflects the increasing competition among miners to solve the complex mathematical problems required to validate transactions and earn Bitcoin rewards.

# %% [markdown]
# Heatmap of Correlation between Variables:

# %%
plot_correlation_heatmap(btc_df)

# %% [markdown]
# This heatmap shows the correlation between all of the variables in the df dataframe. We can see that there is a strong positive correlation between Price and Market Cap, as well as between Hash Rate and Mining Difficulty. There is also a negative correlation between Inflation Rate and ROI 1 Year, which makes sense since a high inflation rate would tend to decrease the ROI for Bitcoin investors.

# %% [markdown]
# 7. Define function to estimate the fundamental component of Bitcoin prices:

# %%
# Moved to Lib

# %% [markdown]
# 9. Define the weights for the economic indicators and macroeconomic factors. For example:

# %%
# Define the weights
w = [0, 0.000000007, 0.00000001, 0.000000002, 2.2]

# %% [markdown]
# 10. Calculate the fundamental component of Bitcoin prices at time t using the equation for $F_t$:

# %%
plot_fundamental_component(btc_df, w)

# %% [markdown]
# We can note here the similarity between the Bitcoin Price and the Fundamental price till it gets to the end where the prediction does not follow the Bitcoin bear market trend. We'd be calibrating the model later on in this research.

# %% [markdown]
# 11. Define the weights for the technical indicators and sentiment analysis. For example:

# %%
alpha = [0.4, 0.3, 0.2, 0.1] # weight for indicators
beta = 0.5 # weight for persistence parameter
k = 14 #window size for the indicators
S_0 = 0 # Initial value of S

# %% [markdown]
# 12. Define a function $f_j$ to calculate the value of each technical indicator and sentiment analysis at time $t$. For example:

# %%
btc_df = plot_technical_sentiment_indicators(btc_df, k)

# %% [markdown]
# 1. The top plot shows the Bitcoin price along with the Moving Average (MA) indicator.
# 2. The middle plot shows the Relative Strength Index (RSI) indicator with two horizontal lines representing the overbought (70) and oversold (30) levels.
# 3. The bottom plot shows the Stochastic Oscillator (SO) indicator with two lines representing the Stochastic Oscillator, as well as two horizontal lines representing the overbought (80) and oversold (20) levels.

# %%
btc_df
# Out:
#            time         Price     hash_rate  transaction_volume  \
# 0    2010-07-31      0.067546  2.464401e-03        8.570089e+02
# 1    2010-08-01      0.061100  2.901437e-03        4.111534e+03
# 2    2010-08-02      0.060000  2.937857e-03        3.789667e+03
# 3    2010-08-03      0.060012  2.755758e-03        1.914656e+03
# 4    2010-08-04      0.057016  2.949997e-03        8.171519e+02
# ...         ...           ...           ...                 ...
# 4564 2023-01-28  23008.809465  3.139301e+08        2.115181e+09
# 4565 2023-01-29  23774.996368  3.114389e+08        2.267370e+09
# 4566 2023-01-30  22799.427262  2.699481e+08        3.771772e+09
# 4567 2023-01-31  23130.051913  2.249568e+08        3.561744e+09
# 4568 2023-02-01  23727.202608  2.679920e+08        3.831801e+09
#
#       mining_difficulty  inflation_rate  bitcoin_trend  year           F_t  \
# 0          2.442132e+02        0.002842       0.001000  2010      0.006260
# ...

# %% [markdown]
# 13. Calculate the value of each technical and economic indicator at time t using the corresponding function $f_j$. For example:

# %%
btc_df
# Out:
#            time         Price     hash_rate  transaction_volume  \
# 0    2010-07-31      0.067546  2.464401e-03        8.570089e+02
# 1    2010-08-01      0.061100  2.901437e-03        4.111534e+03
# 2    2010-08-02      0.060000  2.937857e-03        3.789667e+03
# 3    2010-08-03      0.060012  2.755758e-03        1.914656e+03
# 4    2010-08-04      0.057016  2.949997e-03        8.171519e+02
# ...         ...           ...           ...                 ...
# 4564 2023-01-28  23008.809465  3.139301e+08        2.115181e+09
# 4565 2023-01-29  23774.996368  3.114389e+08        2.267370e+09
# 4566 2023-01-30  22799.427262  2.699481e+08        3.771772e+09
# 4567 2023-01-31  23130.051913  2.249568e+08        3.561744e+09
# 4568 2023-02-01  23727.202608  2.679920e+08        3.831801e+09
#
#       mining_difficulty  inflation_rate  bitcoin_trend  year           F_t  \
# 0          2.442132e+02        0.002842       0.001000  2010      0.006260
# ...

# %%
F_t, btc_df = calculate_fundamental_component(btc_df, w)
S_t, btc_df = calculate_speculative_component(btc_df, alpha, beta, S_0)
#P_t, btc_df = calculated_predicted_price(btc_df, F_t, S_t)
# Out:
# 0 time                  2010-07-31 00:00:00
# Price                            0.067546
# hash_rate                        0.002464
# transaction_volume             857.008939
# mining_difficulty              244.213223
# inflation_rate                   0.002842
# bitcoin_trend                       0.001
# year                                 2010
# F_t                               0.00626
# MA                               0.065739
# RSI                             37.956463
# SO                               48.17416
# Name: 0, dtype: object
# 1 time                  2010-08-01 00:00:00
# Price                              0.0611
# hash_rate                        0.002901
# transaction_volume            4111.534479
# mining_difficulty              244.213223
# inflation_rate                   0.003334
# bitcoin_trend                       0.001
# year                                 2010
# F_t                              0.007377
# MA                               0.063972
# ...

# %% [markdown]
# 15. Calculate the total price of Bitcoin at time $t$ by adding the fundamental component $F_t$ and the speculative component $S_t$:

# %%
plot_heterogeneous_agent_model(btc_df)

# %%
btc_df

# %% [markdown]
# 16. Repeat steps 2-14 for each time period $t$ in the dataset.

# %% [markdown]
# ## Calibration of the model

# %% [markdown]
# Calibrating the parameters of the model would involve finding the optimal values of the weights and the persistence parameter that will give the best fit of the model to the historical data. Here are the steps:

# %% [markdown]
# 1. We create a dataframe containing the historical data, where each variable is a column and each row represents a specific point in time. Make sure the data is properly cleaned and formatted for analysis.

# %%
df = btc.copy(deep=True)

# %% [markdown]
# 2. We define a function that calculates the fundamental component of Bitcoin prices, given the weights and the economic indicators and macroeconomic factors. This function should take as input a row of the dataframe representing a specific point in time, extract the relevant variables, and apply the formula for the fundamental component.

# %%
def calculate_fundamental(row, weights):
    H = row['hash_rate']
    TV = row['transaction_volume']
    MD = row['mining_difficulty']
    IR = row['inflation_rate']
    return weights[0] + weights[1]*H + weights[2]*TV + weights[3]*MD + weights[4]*IR

# %% [markdown]
# 3. We define a function that calculates the speculative component of Bitcoin prices, given the weights, the persistence parameter, and the technical indicators and sentiment analysis. This function should take as input a row of the dataframe representing a specific point in time, extract the relevant variables, and apply the formula for the speculative component.

# %%
def calculate_speculative(row, weights, beta):
    MA = row['MA']
    RSI = row['RSI']
    SO = row['SO']
    GT = row['bitcoin_trend']
    S_prev = row['S_t']
    return weights[0]*MA + weights[1]*RSI + weights[2]*SO + weights[3]*GT + beta*S_prev

# %% [markdown]
# 4. We define a function that calculates the predicted Bitcoin price, given the weights, the persistence parameter, and the data for a specific point in time. This function should call the functions defined in steps 1 and 2 to calculate the fundamental and speculative components, and add them together to get the predicted price.

# %%
def predict_price(row, weights_fundamental, weights_speculative, beta):
    F = calculate_fundamental(row, weights_fundamental)
    S = calculate_speculative(row, weights_speculative, beta)
    return F + S

# %% [markdown]
# 5. We define a function that calculates the mean squared error (MSE) between the predicted prices and the actual prices in the testing set. This function should take as input the weights and the persistence parameter, and use them to call the predict_price function for each row in the testing set.

# %%
def calculate_mse(df_test, weights_fundamental, weights_speculative, beta):
    df_test['P_t'] = df_test.apply(predict_price, args=(weights_fundamental, weights_speculative, beta), axis=1)
    mse = ((df_test['Price'] - df_test['P_t'])**2).mean()
    return mse

# %% [markdown]
# 6. We split the data into training and testing sets. We will use the training set to optimize the parameters and the testing set to evaluate the performance of the model.

# %%
train_size = int(0.95 * len(df))
df_train = df[:train_size]
df_test = df[train_size:]

# %% [markdown]
# 7. We define an optimization function that takes as input the data, the initial guesses for the weights and the persistence parameter, and the optimization method. This function should use the specified optimization method to minimize the MSE calculated in step 5, by varying the weights and the persistence parameter.

# %%
from scipy.optimize import minimize

def optimize_parameters(data, initial_guess_fundamental, initial_guess_speculative, initial_guess_beta, method='Nelder-Mead'):
    
    def objective_function(parameters):
        weights_fundamental = parameters[:5]
        weights_speculative = parameters[5:10]
        beta = parameters[10]
        mse = calculate_mse(df_train, weights_fundamental, weights_speculative, beta)
        return mse
    
    initial_guess = np.concatenate([initial_guess_fundamental, initial_guess_speculative, [initial_guess_beta]])
    
    result = minimize(objective_function, initial_guess, method=method)
    
    weights_fundamental = result.x[:5]
    weights_speculative = result.x[5:10]
    beta = result.x[10]
    
    return weights_fundamental, weights_speculative, beta

# %% [markdown]
# 8. We call the optimization function with the initial guesses for the weights and the persistence parameter, and the optimization method.

# %%
initial_guess_fundamental = [1, 0.000000007, 0.00000001, 0.000000002, 1]
initial_guess_speculative = [1, 1, 1, 1, 1]
initial_guess_beta = 0.5

weights_fundamental, weights_speculative, beta = optimize_parameters(df_train, initial_guess_fundamental, initial_guess_speculative, initial_guess_beta)

# %%
weights_fundamental, weights_speculative, beta

# %% [markdown]
# 9. We use the optimized parameters to make predictions on the testing set, and calculate the MSE and RMSE to evaluate the performance of the model.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

def evaluate_model(df_test, weights_fundamental, weights_speculative, beta):
    df_test['P_t'] = df_test.apply(predict_price, args=(weights_fundamental, weights_speculative, beta), axis=1)
    mae = mean_absolute_error(df_test['Price'], df_test['P_t'])
    mse = mean_squared_error(df_test['Price'], df_test['P_t'], squared=True)
    rmse = mean_squared_error(df_test['Price'], df_test['P_t'], squared=False)
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"Root Mean Squared Error (MSE): {mse}")
    print(f"Root Mean Squared Error (RMSE): {rmse}")

# %%
evaluate_model(df_test, weights_fundamental, weights_speculative, beta)

# %% [markdown]
# 10. To analyze the results, we can visually inspect the plot to see how well the model predicts the actual prices. We can also calculate some metrics such as the mean absolute error (MAE) and root mean squared error (RMSE) to quantitatively evaluate the performance of the model. For example:

# %%
def plot_prices(df_test, weights_fundamental, weights_speculative, beta):
    df_test['P_t'] = df_test.apply(predict_price, args=(weights_fundamental, weights_speculative, beta), axis=1)
    plt.figure(figsize=(12, 6))
    plt.plot(df_test['time'], df_test['Price'], label='Actual price')
    plt.plot(df_test['time'], df_test['P_t'], label='Predicted price')
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.legend()
    plt.show()

# %%
plot_prices(df_test, weights_fundamental, weights_speculative, beta)

# %% [markdown]
# ## Testing of the model

# %% [markdown]
# ## Reference
# - we use the btc data from: https://coinmetrics.io/community-network-data/, size: 10.3 MB
# - we use btc tweets from: https://www.kaggle.com/code/johngiannou/bitcoin-tweets-sentiment-analysis, size: 2.1 GB
# - Google trends data https://trends.google.com/trends/explore?date=all&q=bitcoin
# - Chat: https://chat.openai.com/chat/ef51b46d-bb76-4913-8461-6334d0ce3c6a
